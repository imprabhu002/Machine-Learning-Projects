# %% [markdown]
# The term "bank churn" refers to the phenomenon of customers switching their bank accounts from one financial institution to another frequently. It is also known as "bank account churn" or "bank switching." Bank churn typically occurs when customers are dissatisfied with their current bank's services, fees, or overall customer experience, and they decide to move their accounts to a different bank that offers better benefits or meets their needs more effectively.

# %%
import pandas as pd 
import numpy as np 
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("E:\python files\Customer-Churn-Records.csv")

# %%
df
# Out:
#       RowNumber  CustomerId    Surname  CreditScore Geography  Gender  Age
# 0             1    15634602   Hargrave          619    France  Female   42  \
# 1             2    15647311       Hill          608     Spain  Female   41
# 2             3    15619304       Onio          502    France  Female   42
# 3             4    15701354       Boni          699    France  Female   39
# 4             5    15737888   Mitchell          850     Spain  Female   43
# ...         ...         ...        ...          ...       ...     ...  ...
# 9995       9996    15606229   Obijiaku          771    France    Male   39
# 9996       9997    15569892  Johnstone          516    France    Male   35
# 9997       9998    15584532        Liu          709    France  Female   36
# 9998       9999    15682355  Sabbatini          772   Germany    Male   42
# 9999      10000    15628319     Walker          792    France  Female   28
#
#       Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember
# ...

# %%
df[(df.Age > 20) & (df.Geography == 'Germany')].describe()
# Out:
#          RowNumber    CustomerId  CreditScore          Age       Tenure
# count  2489.000000  2.489000e+03  2489.000000  2489.000000  2489.000000  \
# mean   4997.881479  1.569045e+07   651.425874    39.938530     5.017276
# std    2914.665846  7.322535e+04    98.212735    10.394269     2.932538
# min       8.000000  1.556578e+07   350.000000    21.000000     0.000000
# 25%    2465.000000  1.562726e+07   584.000000    33.000000     2.000000
# 50%    4997.000000  1.568979e+07   651.000000    38.000000     5.000000
# 75%    7576.000000  1.575533e+07   722.000000    45.000000     8.000000
# max    9999.000000  1.581566e+07   850.000000    84.000000    10.000000
#
#              Balance  NumOfProducts    HasCrCard  IsActiveMember
# count    2489.000000    2489.000000  2489.000000     2489.000000  \
# mean   119703.619759       1.521495     0.714745        0.496987
# std     27032.546167       0.620231     0.451627        0.500091
# ...

# %%
df.columns
# Out:
# Index(['RowNumber', 'CustomerId', 'Surname', 'CreditScore', 'Geography',
#        'Gender', 'Age', 'Tenure', 'Balance', 'NumOfProducts', 'HasCrCard',
#        'IsActiveMember', 'EstimatedSalary', 'Exited', 'Complain',
#        'Satisfaction Score', 'Card Type', 'Point Earned'],
#       dtype='object')

# %%
b = df[['RowNumber','CustomerId']]
b.head(2)
# Out:
#    RowNumber  CustomerId
# 0          1    15634602
# 1          2    15647311

# %%
c = ['Age','Balance']
df[c].head(2)
# Out:
#    Age   Balance
# 0   42      0.00
# 1   41  83807.86

# %%
df.query("Gender == 'Male'").head(1)
# Out:
#    RowNumber  CustomerId Surname  CreditScore Geography Gender  Age  Tenure
# 5          6    15574012     Chu          645     Spain   Male   44       8  \
#
#      Balance  NumOfProducts  HasCrCard  IsActiveMember  EstimatedSalary
# 5  113755.78              2          1               0        149756.71  \
#
#    Exited  Complain  Satisfaction Score Card Type  Point Earned
# 5       1         1                   5   DIAMOND           484

# %%
df.query("Age >= 80").head()
# Out:
#       RowNumber  CustomerId     Surname  CreditScore Geography  Gender  Age
# 310         311    15712287  Pokrovskii          652    France  Female   80  \
# 766         767    15810864  Williamson          700    France  Female   82
# 2458       2459    15813303     Rearick          513     Spain    Male   88
# 3033       3034    15578006         Yao          787    France  Female   85
# 3387       3388    15798024        Lori          537   Germany    Male   84
#
#       Tenure   Balance  NumOfProducts  HasCrCard  IsActiveMember
# 310        4      0.00              2          1               1  \
# 766        2      0.00              2          0               1
# 2458      10      0.00              2          1               1
# 3033      10      0.00              2          1               1
# 3387       8  92242.34              1          1               1
#
#       EstimatedSalary  Exited  Complain  Satisfaction Score Card Type
# ...

# %%
df[df.Age == 20].describe()
# Out:
#         RowNumber    CustomerId  CreditScore   Age     Tenure        Balance
# count    40.00000  4.000000e+01    40.000000  40.0  40.000000      40.000000  \
# mean   5358.82500  1.570545e+07   665.050000  20.0   5.075000   76038.890000
# std    2762.19346  6.416820e+04    82.325791   0.0   2.921077   70271.544315
# min     234.00000  1.556684e+07   463.000000  20.0   0.000000       0.000000
# 25%    3009.75000  1.566513e+07   610.000000  20.0   3.000000       0.000000
# 50%    5161.00000  1.572459e+07   659.500000  20.0   4.500000  100169.600000
# 75%    7535.00000  1.575810e+07   716.000000  20.0   8.000000  133435.250000
# max    9941.00000  1.579197e+07   850.000000  20.0  10.000000  204223.030000
#
#        NumOfProducts  HasCrCard  IsActiveMember  EstimatedSalary     Exited
# count      40.000000  40.000000       40.000000        40.000000  40.000000  \
# mean        1.550000   0.650000        0.475000     97705.542000   0.050000
# ...

# %%
import re
df.columns = [re.sub(" ","_" , col.lower()) for col in df.columns]
df.columns
# Out:
# Index(['rownumber', 'customerid', 'surname', 'creditscore', 'geography',
#        'gender', 'age', 'tenure', 'balance', 'numofproducts', 'hascrcard',
#        'isactivemember', 'estimatedsalary', 'exited', 'complain',
#        'satisfaction_score', 'card_type', 'point_earned'],
#       dtype='object')

# %%
df['gender'].value_counts().plot(kind = 'pie', autopct = '%.2f')
plt.show()

# %%
plt.hist(df['age'],bins = 20);

# %%
sns.distplot(df['age']);
# Out:
# C:\Users\Ranil\AppData\Local\Temp\ipykernel_16440\1462740167.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['age']);

# %%
df.columns
# Out:
# Index(['rownumber', 'customerid', 'surname', 'creditscore', 'geography',
#        'gender', 'age', 'tenure', 'balance', 'numofproducts', 'hascrcard',
#        'isactivemember', 'estimatedsalary', 'exited', 'complain',
#        'satisfaction_score', 'card_type', 'point_earned'],
#       dtype='object')

# %%
sns.histplot(df, x="estimatedsalary")
sns.rugplot(df, x="estimatedsalary");

# %%
sns.countplot(x = 'gender' , data = df , hue = 'exited')
# Out:
# <Axes: xlabel='gender', ylabel='count'>

# %%
plt.boxplot(df['age'].fillna(0.0));

# %%
sns.scatterplot(df['age'],color = 'red');

# %%
df.columns
# Out:
# Index(['rownumber', 'customerid', 'surname', 'creditscore', 'geography',
#        'gender', 'age', 'tenure', 'balance', 'numofproducts', 'hascrcard',
#        'isactivemember', 'estimatedsalary', 'exited', 'complain',
#        'satisfaction_score', 'card_type', 'point_earned'],
#       dtype='object')

# %%
sns.scatterplot(x = 'age' , y = 'estimatedsalary' , data = df , hue = 'complain')
# Out:
# <Axes: xlabel='age', ylabel='estimatedsalary'>

# %%
sns.scatterplot(x='age', y='estimatedsalary', data=df, hue='complain', size='gender')
# Out:
# <Axes: xlabel='age', ylabel='estimatedsalary'>

# %%
df.columns
# Out:
# Index(['rownumber', 'customerid', 'surname', 'creditscore', 'geography',
#        'gender', 'age', 'tenure', 'balance', 'numofproducts', 'hascrcard',
#        'isactivemember', 'estimatedsalary', 'exited', 'complain',
#        'satisfaction_score', 'card_type', 'point_earned'],
#       dtype='object')

# %%
sns.barplot(x = df['numofproducts'], y = df['geography']);

# %%
sns.barplot(x = df['age'], y = df['gender'], hue = df["geography"])
# Out:
# <Axes: xlabel='age', ylabel='gender'>

# %%
sns.boxplot(x = df['gender'] , y = df['age'], hue = df['hascrcard'])
# Out:
# <Axes: xlabel='gender', ylabel='age'>

# %%
sns.heatmap(pd.crosstab(df['gender'],df['estimatedsalary']))
# Out:
# <Axes: xlabel='estimatedsalary', ylabel='gender'>

# %%
import plotly.express as px

# %%
px.scatter(x = df['age'],color = df['age'])

# %%
px.scatter(x = df['age'], y = df['estimatedsalary'], color = df['age'])

# %%
df.groupby('gender')['numofproducts'].mean() # series
# Out:
# gender
# Female    1.544134
# Male      1.518600
# Name: numofproducts, dtype: float64

# %%
df.groupby('gender')[['numofproducts']].describe() # gives a DF
# Out:
#        numofproducts
#                count      mean       std  min  25%  50%  75%  max
# gender
# Female        4543.0  1.544134  0.603254  1.0  1.0  1.0  2.0  4.0
# Male          5457.0  1.518600  0.562834  1.0  1.0  1.0  2.0  4.0

# %%
(df.groupby('gender')[['numofproducts']].agg(['min','mean','max'])) # agg functions
# Out:
#        numofproducts
#                  min      mean max
# gender
# Female             1  1.544134   4
# Male               1  1.518600   4

# %%
df.exited.value_counts() # counts no of apprncs for given column
# Out:
# exited
# 0    7962
# 1    2038
# Name: count, dtype: int64

# %%
df.groupby('gender')['estimatedsalary'].mean()
# Out:
# gender
# Female    100601.541382
# Male       99664.576931
# Name: estimatedsalary, dtype: float64

# %%
df['averagesalary'] = df.groupby('gender')['estimatedsalary'].transform("mean")
df[['averagesalary']].describe()
# Out:
#        averagesalary
# count   10000.000000
# mean   100090.239881
# std       466.544609
# min     99664.576931
# 25%     99664.576931
# 50%     99664.576931
# 75%    100601.541382
# max    100601.541382

# %%
# df.fillna() # to fill null value with something

# %%
df.columns
# Out:
# Index(['rownumber', 'customerid', 'surname', 'creditscore', 'geography',
#        'gender', 'age', 'tenure', 'balance', 'numofproducts', 'hascrcard',
#        'isactivemember', 'estimatedsalary', 'exited', 'complain',
#        'satisfaction_score', 'card_type', 'point_earned', 'averagesalary'],
#       dtype='object')

# %%
df.rename(columns = {'customerID':'customerid'});

# %%
df['gen2'] = df['gender'].replace({'Male':'m','Female':'f'})
df.head()
# Out:
#    rownumber  customerid   surname  creditscore geography  gender  age
# 0          1    15634602  Hargrave          619    France  Female   42  \
# 1          2    15647311      Hill          608     Spain  Female   41
# 2          3    15619304      Onio          502    France  Female   42
# 3          4    15701354      Boni          699    France  Female   39
# 4          5    15737888  Mitchell          850     Spain  Female   43
#
#    tenure    balance  numofproducts  hascrcard  isactivemember
# 0       2       0.00              1          1               1  \
# 1       1   83807.86              1          0               1
# 2       8  159660.80              3          1               0
# 3       1       0.00              2          0               0
# 4       2  125510.82              1          1               1
#
#    estimatedsalary  exited  complain  satisfaction_score card_type
# 0        101348.88       1         1                   2   DIAMOND  \
# ...

# %%
df.groupby('gen2')[['tenure']].describe()
# Out:
#       tenure
#        count      mean       std  min  25%  50%  75%   max
# gen2
# f     4543.0  4.966102  2.910252  0.0  2.0  5.0  7.0  10.0
# m     5457.0  5.051677  2.876726  0.0  3.0  5.0  8.0  10.0

# %%
df.isnull().sum()
# Out:
# rownumber             0
# customerid            0
# surname               0
# creditscore           0
# geography             0
# gender                0
# age                   0
# tenure                0
# balance               0
# numofproducts         0
# hascrcard             0
# isactivemember        0
# estimatedsalary       0
# exited                0
# complain              0
# satisfaction_score    0
# card_type             0
# point_earned          0
# averagesalary         0
# gen2                  0
# dtype: int64

# %%
df.sample(3)
# Out:
#       rownumber  customerid    surname  creditscore geography gender  age
# 7167       7168    15732884  Trevisano          676    France   Male   29  \
# 8139       8140    15770539    Walters          792    France   Male   30
# 5302       5303    15636700      Marsh          701    France   Male   39
#
#       tenure    balance  numofproducts  hascrcard  isactivemember
# 7167       7  131959.86              1          0               0  \
# 8139       1  127187.86              1          1               1
# 5302       9  140236.98              1          0               1
#
#       estimatedsalary  exited  complain  satisfaction_score card_type
# 7167        189268.81       0         0                   2    SILVER  \
# 8139        113553.42       0         0                   3    SILVER
# 5302        146651.99       0         0                   2  PLATINUM
#
#       point_earned  averagesalary gen2
# 7167           304   99664.576931    m
# ...

# %%
df = pd.read_csv("E:\python files\Customer-Churn-Records.csv")

# %% [markdown]
# ## Data visualization

# %%
# Churn distribution
plt.figure(figsize=(5, 5))
churn_counts = df['Exited'].value_counts()
plt.pie(churn_counts, labels=['Retained', 'Churned'], autopct='%1.1f%%', startangle=45)
plt.axis('equal')
plt.title('Churn Distribution')
plt.show()

# %%
# Churn by gender
plt.figure(figsize=(8, 6))
sns.countplot(x='Gender', hue='Exited', data=df)
plt.title('Churn by Gender')
plt.show()

# %% [markdown]
# #### It appears that the churn rate is relatively similar across both genders.

# %%
# Churn by age group
df['AgeGroup'] = pd.cut(df['Age'], bins=[0, 30, 40, 50, 60, np.inf], labels=['<30', '30-40', '40-50', '50-60', '60+'])
plt.figure(figsize=(8, 6))
sns.countplot(x='AgeGroup', hue='Exited', data=df)
plt.title('Churn by Age Group')
plt.show()

# %% [markdown]
# #### Customers aged between 50-60 tend to churn the most, followed by the 40-50 age group.

# %%
# Churn by Number of Products:
plt.figure(figsize=(8, 6))
sns.countplot(x='NumOfProducts', hue='Exited', data=df)
plt.title('Churn by Number of Products')
plt.show()

# %% [markdown]
# #### The number of products held by customers can impact churn. Customers with fewer products may be less likely to churn, while those with more products may have a higher churn rate. Further analysis is required to understand the specific relationship.

# %%
# Churn by geography
plt.figure(figsize=(8, 6))
sns.countplot(x='Geography', hue='Exited', data=df)
plt.title('Churn by Geography')
plt.show()

# %% [markdown]
# ####  Germany stands out in terms of having a relatively higher count of churned customers.

# %%
# Churn by Activity Status
plt.figure(figsize=(8, 6))
sns.countplot(x='IsActiveMember', hue='Exited', data=df)
plt.title('Churn by Activity Status')
plt.show()

# %% [markdown]
# #### Customer activity status is another important factor. Active members appear to have a lower churn rate compared to inactive members. This suggests that engaged and active customers are more likely to stay with the bank.

# %%
# Churn by Balance:

plt.figure(figsize=(10, 6))
sns.boxplot(x='Exited', y='Balance', data=df)
plt.title('Churn by Balance')
plt.show()

# %% [markdown]
# #### The distribution of account balances does not show a clear distinction between churned and retained customers. Further analysis and feature engineering may be required to explore the relationship between balance and churn in more detail.

# %% [markdown]
# ## Prediction models:

# %%
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score

X = df.loc[:,['CreditScore', 'Geography', 'Gender', 'Age', 'Tenure','Balance', 'NumOfProducts', 'HasCrCard', 'IsActiveMember', 'EstimatedSalary','Complain', 'Satisfaction Score', 'Card Type', 'Point Earned']]
Y = df['Exited']

X = pd.get_dummies(X)

numerical_columns = df.select_dtypes(include=['int', 'float']).columns.to_list()
for col in numerical_columns:
    df[col] = (df[col] - df[col].mean())/df[col].std()
X_train, X_test, y_train, y_test = train_test_split(X, Y, test_size=0.3, random_state=5)

# %% [markdown]
# ### XGBoost classifier

# %%
import xgboost as xgb

# Define the XGBoost classifier model
model = xgb.XGBClassifier()

# Train the model
model.fit(X_train, y_train)

# Make predictions on the test set
y_pred = model.predict(X_test)

# Calculate accuracy on the test set
accuracy = accuracy_score(y_test, y_pred)
print(accuracy)
# Out:
# 0.9993333333333333

# %%
from sklearn.metrics import accuracy_score, f1_score, precision_score, recall_score
from sklearn.linear_model import LinearRegression, LogisticRegression, Lasso
from sklearn.neighbors import KNeighborsClassifier
from sklearn.ensemble import RandomForestClassifier, GradientBoostingClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.svm import SVC

# %%
models = {
    "Linear Regression": LinearRegression(),
    "Logistic Regression": LogisticRegression(C=0.1),
    "KNeighborsClassifier": KNeighborsClassifier(n_neighbors=5),
    "RandomForestClassifier": RandomForestClassifier(n_estimators=10),
    "Gradient Boosting": GradientBoostingClassifier(),
    "DecisionTreeClassifier": DecisionTreeClassifier(),
    "Naive Bayes": GaussianNB(),
    "Support Vector Machine": SVC(),
}

results = []
for name, model in models.items():
    if name == "Linear Regression":
        model.fit(X_train, y_train)
        y_train_pred = model.predict(X_train)
        y_pred = model.predict(X_test)
        train_acc = "N/A"
        test_acc = "N/A"
        f1 = "N/A"
        precision = "N/A"
        recall = "N/A"
    else:
        model.fit(X_train, y_train)
        y_train_pred = model.predict(X_train)
        y_pred = model.predict(X_test)
        train_acc = accuracy_score(y_train, y_train_pred)
        test_acc = accuracy_score(y_test, y_pred)
        f1 = f1_score(y_test, y_pred, average='weighted')
        precision = precision_score(y_test, y_pred, average='weighted')
        recall = recall_score(y_test, y_pred, average='weighted')
    results.append([name, train_acc, test_acc, f1, precision, recall])

df_results = pd.DataFrame(results, columns=["Model Name", "Training Accuracy", "Test Accuracy", "F1 Score", "Precision", "Recall"])
df_results
# Out:
# c:\Users\Ranil\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning:
#
# Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#                Model Name Training Accuracy Test Accuracy  F1 Score Precision
# 0       Linear Regression               N/A           N/A       N/A       N/A  \
# 1     Logistic Regression          0.787429      0.793667  0.726395  0.719739
# 2    KNeighborsClassifier             0.814      0.762333  0.715758  0.690349
# 3  RandomForestClassifier          0.999571      0.999333  0.999334  0.999336
# 4       Gradient Boosting          0.999857      0.998667  0.998668   0.99867
# 5  DecisionTreeClassifier               1.0      0.995333  0.995321  0.995332
# 6             Naive Bayes          0.795857         0.799  0.739906  0.744555
# ...

# %% [markdown]
# In this case, the error suggests that our target variable has a mix of binary (categorical) and continuous (numeric) values. However, the classification metrics you are using, such as accuracy_score, f1_score, precision_score, and recall_score, are appropriate only for binary or categorical targets.
#
# The LinearRegression model we included in the models dictionary is a regression model, which is used for predicting continuous numerical values, not for classification tasks with categorical targets.
#
# To resolve this issue, we need to ensure that you are using a suitable model and corresponding metrics based on the nature of your target variable. If our target variable represents categories or classes, you should use a classification model and classification metrics. If our target variable represents continuous numerical values, we should use a regression model and regression evaluation metrics.

# %% [markdown]
# ### Catboost classifier

# %%
#Creating catboost classifier model
import catboost as cat
cat_model = cat.CatBoostClassifier(
        iterations=8,
        max_depth=6,
    )
cat_model.fit(X_train,y_train)
cat_model.score(X_test,y_test)
# Out:
# Learning rate set to 0.5
# 0:	learn: 0.0534458	total: 139ms	remaining: 973ms
# 1:	learn: 0.0181836	total: 142ms	remaining: 425ms
# 2:	learn: 0.0099796	total: 144ms	remaining: 240ms
# 3:	learn: 0.0077578	total: 147ms	remaining: 147ms
# 4:	learn: 0.0073490	total: 150ms	remaining: 89.7ms
# 5:	learn: 0.0071901	total: 152ms	remaining: 50.8ms
# 6:	learn: 0.0068789	total: 155ms	remaining: 22.2ms
# 7:	learn: 0.0065381	total: 158ms	remaining: 0us
# 0.9993333333333333

# %% [markdown]
# ### Both models gave 99.93% accuracy

# %% [markdown]
# #### Here is an Deep Learning model for the same

# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout

X_train, X_test, y_train, y_test = train_test_split(X, Y, test_size=0.3, random_state=5)
scaler = StandardScaler()
X_train_scaled, X_test_scaled = scaler.fit_transform(X_train), scaler.transform(X_test)

model = Sequential([Dense(64, activation='relu', input_shape=(X_train_scaled.shape[1],)), Dropout(0.2),
                    Dense(64, activation='relu'), Dropout(0.2), Dense(1, activation='sigmoid')])
model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])
model.fit(X_train_scaled, y_train, epochs=10, batch_size=32, verbose=1)

accuracy = (model.predict(X_test_scaled) > 0.5).mean()
print("Accuracy: %.2f%%" % (accuracy * 100))
# Out:
# Epoch 1/10
# 219/219 [==============================] - 1s 1ms/step - loss: 0.1605 - accuracy: 0.9417
# Epoch 2/10
# 219/219 [==============================] - 0s 1ms/step - loss: 0.0163 - accuracy: 0.9980
# Epoch 3/10
# 219/219 [==============================] - 0s 1ms/step - loss: 0.0131 - accuracy: 0.9981
# Epoch 4/10
# 219/219 [==============================] - 0s 1ms/step - loss: 0.0111 - accuracy: 0.9983
# Epoch 5/10
# 219/219 [==============================] - 0s 1ms/step - loss: 0.0106 - accuracy: 0.9983
# Epoch 6/10
# 219/219 [==============================] - 0s 1ms/step - loss: 0.0089 - accuracy: 0.9983
# Epoch 7/10
# 219/219 [==============================] - 0s 1ms/step - loss: 0.0101 - accuracy: 0.9981
# Epoch 8/10
# 219/219 [==============================] - 0s 1ms/step - loss: 0.0088 - accuracy: 0.9980
# Epoch 9/10
# 219/219 [==============================] - 0s 1ms/step - loss: 0.0079 - accuracy: 0.9979
# Epoch 10/10
# ...

# %%
from sklearn.metrics import  confusion_matrix
cm = confusion_matrix(y_test,y_pred)
cm
# Out:
# array([[2403,    0],
#        [ 597,    0]], dtype=int64)

# %%
from sklearn.metrics import ConfusionMatrixDisplay
ConfusionMatrixDisplay(cm).plot()

# %% [markdown]
# ### Computing the class weight for computational informations(if needed only da)

# %% [markdown]
# Class weights are used in machine learning algorithms to address class imbalance, where one class has significantly more or fewer samples than the other class(es). In the case of a CatBoost classifier, calculating class weights can help improve the model's performance when dealing with imbalanced datasets.
#
# When a dataset is imbalanced, the algorithm may be biased towards the majority class, resulting in poor predictions for the minority class. By assigning higher weights to the minority class during the training process, the algorithm can give more importance to these samples and learn to better distinguish them.

# %%
# from catboost import CatBoostClassifier
# from sklearn.utils.class_weight import compute_class_weight
# classes = np.unique(y_train)
# weights = compute_class_weight(class_weight='balanced', classes=classes, y=y_train)
# class_weights = dict(zip(classes, weights))
# bro47 = CatBoostClassifier(loss_function='MultiClassOneVsAll', class_weights=class_weights)
# bro47.fit(X_train, y_train)

# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
image_path = r'E:\python files\jhonny bhai.jpeg'  # Replace with the actual path to your image file
img = mpimg.imread(image_path)
plt.imshow(img)
plt.show()
